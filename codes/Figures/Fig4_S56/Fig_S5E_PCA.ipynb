# %% [markdown]
# # Notes

# %% [markdown]
# # Load Modules

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['font.sans-serif'] = 'Arial'
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
# %matplotlib inline

# %%
def load_data(file_pairs,src_dir='',dst_dir='.'):
    import os
    if not os.path.isdir(dst_dir):
        os.mkdir(dst_dir)
    for file_pair in file_pairs:
        src = os.path.abspath(os.path.expanduser(os.path.join(src_dir,file_pair[0])))
        dst = os.path.expanduser(os.path.join(dst_dir,file_pair[1]))
        if os.path.isfile(dst):
            os.remove(dst)
        if not os.path.islink(dst):
            os.symlink(src,dst)

def load_data_suffixes(file_pairs, src_dir='', dst_dir='.', suffixes=None):
    import os
    if not os.path.isdir(dst_dir):
        os.mkdir(dst_dir)
    if not suffixes:
        for file_pair in file_pairs:
            src = os.path.abspath(os.path.expanduser(os.path.join(src_dir, file_pair[0])))
            dst = os.path.expanduser(os.path.join(dst_dir, file_pair[1]))
            if os.path.isfile(dst):
                os.remove(dst)
            if not os.path.islink(dst):
                os.symlink(src, dst)
    else:
        for file_pair in file_pairs:
            for suffix_pair in suffixes:
                src = os.path.abspath(os.path.expanduser(
                    os.path.join(src_dir, file_pair[0] + suffix_pair[0])))
                dst = os.path.expanduser(
                    os.path.join(dst_dir, file_pair[1] + suffix_pair[1]))
                if os.path.isfile(dst):
                    os.remove(dst)
                if not os.path.islink(dst):
                    os.symlink(src, dst)

# %% [markdown]
# # Load data

# %%
import os
os.chdir('/mnt/Storage/home/wangyiman/fitCUTRUN/analysis/RNAseq/expression_change')

# %%
file_pairs = [
    [
        'RNA_seq_RNA-Fc_Nanog_dome_rep3_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_dome_rep3_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-Fc_Nanog_dome_rep4_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_dome_rep4_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-Fc_Nanog_1k_rep3_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_1k_rep3_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-Fc_Nanog_1k_rep4_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_1k_rep4_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-Fc_Nanog_256_rep3_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_256_rep3_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-Fc_Nanog_256_rep4_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_256_rep4_ensGene_coverage.txt'
    ],

    [
        'RNA_seq_RNA-WT_dome_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-WT_dome_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-WT_dome_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-WT_dome_rep2_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-WT_1k_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-WT_1k_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-WT_1k_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-WT_1k_rep2_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-WT_256_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-WT_256_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-WT_256_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-WT_256_rep2_ensGene_coverage.txt'
    ],
    
    [
        'RNA_seq_RNA-H2O_dome_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-H2O_dome_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-H2O_dome_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-H2O_dome_rep2_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-H2O_1k_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-H2O_1k_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-H2O_1k_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-H2O_1k_rep2_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-H2O_256_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-H2O_256_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-H2O_256_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-H2O_256_rep2_ensGene_coverage.txt'
    ],
]
load_data(
    file_pairs,
    src_dir='~/fitCUTRUN/RNAseq/20210930_RNA_H2O_NanogFc_WT_256_1k_dome/2_expression_value/',
    dst_dir='.')

# %%
file_pairs = [
    [
        'RNA_seq_RNA-Fc_Nanog_dome_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_dome_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-Fc_Nanog_dome_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_dome_rep2_ensGene_coverage.txt'
    ],
]
load_data(
    file_pairs,
    src_dir='~/fitCUTRUN/RNAseq/20210730_RNA_NanogFc_dome/2_expression_value/',
    dst_dir='.')

# %%
file_pairs = [   
    [
        'RNA_seq_RNA-Fc_Nanog_1k_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_1k_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-Fc_Nanog_1k_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_1k_rep2_ensGene_coverage.txt'
    ],
]
load_data(
    file_pairs,
    src_dir='~/fitCUTRUN/RNAseq/20210802_RNA_ATF1Fc-NanogFc_K562-1k/2_expression_value/',
    dst_dir='.')

# %%
file_pairs = [
    [
        'RNA_seq_RNA-Fc_Nanog_256_rep1_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_256_rep1_ensGene_coverage.txt'
    ],
    [
        'RNA_seq_RNA-Fc_Nanog_256_rep2_ensGene_coverage.txt',
        'RNA_seq_RNA-Fc_Nanog_256_rep2_ensGene_coverage.txt'
    ],
]
load_data(
    file_pairs,
    src_dir='~/fitCUTRUN/RNAseq/20210804_RNA_NanogFc_256/2_expression_value/',
    dst_dir='.')

# %% [markdown]
# # merge expression

# %%
# %%bash
#
# echo nanog_rFc_dome_rep4 RNA_seq_RNA-Fc_Nanog_dome_rep4_ensGene_coverage.txt  >  sample_list.txt
# echo nanog_rFc_dome_rep3 RNA_seq_RNA-Fc_Nanog_dome_rep3_ensGene_coverage.txt  >> sample_list.txt
# echo nanog_rFc_dome_rep2 RNA_seq_RNA-Fc_Nanog_dome_rep2_ensGene_coverage.txt  >> sample_list.txt
# echo nanog_rFc_dome_rep1 RNA_seq_RNA-Fc_Nanog_dome_rep1_ensGene_coverage.txt  >> sample_list.txt
# echo nanog_rFc_1k_rep4   RNA_seq_RNA-Fc_Nanog_1k_rep4_ensGene_coverage.txt    >> sample_list.txt
# echo nanog_rFc_1k_rep3   RNA_seq_RNA-Fc_Nanog_1k_rep3_ensGene_coverage.txt    >> sample_list.txt
# echo nanog_rFc_1k_rep2   RNA_seq_RNA-Fc_Nanog_1k_rep2_ensGene_coverage.txt    >> sample_list.txt
# echo nanog_rFc_1k_rep1   RNA_seq_RNA-Fc_Nanog_1k_rep1_ensGene_coverage.txt    >> sample_list.txt
# echo nanog_rFc_256_rep4  RNA_seq_RNA-Fc_Nanog_256_rep4_ensGene_coverage.txt   >> sample_list.txt
# echo nanog_rFc_256_rep3  RNA_seq_RNA-Fc_Nanog_256_rep3_ensGene_coverage.txt   >> sample_list.txt
# echo nanog_rFc_256_rep2  RNA_seq_RNA-Fc_Nanog_256_rep2_ensGene_coverage.txt   >> sample_list.txt
# echo nanog_rFc_256_rep1  RNA_seq_RNA-Fc_Nanog_256_rep1_ensGene_coverage.txt   >> sample_list.txt
#
# echo WT_dome_rep2        RNA_seq_RNA-WT_dome_rep2_ensGene_coverage.txt        >> sample_list.txt
# echo WT_dome_rep1        RNA_seq_RNA-WT_dome_rep1_ensGene_coverage.txt        >> sample_list.txt
# echo WT_1k_rep2          RNA_seq_RNA-WT_1k_rep2_ensGene_coverage.txt          >> sample_list.txt
# echo WT_1k_rep1          RNA_seq_RNA-WT_1k_rep1_ensGene_coverage.txt          >> sample_list.txt
# echo WT_256_rep2         RNA_seq_RNA-WT_256_rep2_ensGene_coverage.txt         >> sample_list.txt
# echo WT_256_rep1         RNA_seq_RNA-WT_256_rep1_ensGene_coverage.txt         >> sample_list.txt
#
# echo H2O_dome_rep2        RNA_seq_RNA-H2O_dome_rep2_ensGene_coverage.txt      >> sample_list.txt
# echo H2O_dome_rep1        RNA_seq_RNA-H2O_dome_rep1_ensGene_coverage.txt      >> sample_list.txt
# echo H2O_1k_rep2          RNA_seq_RNA-H2O_1k_rep2_ensGene_coverage.txt        >> sample_list.txt
# echo H2O_1k_rep1          RNA_seq_RNA-H2O_1k_rep1_ensGene_coverage.txt        >> sample_list.txt
# echo H2O_256_rep2         RNA_seq_RNA-H2O_256_rep2_ensGene_coverage.txt       >> sample_list.txt
# echo H2O_256_rep1         RNA_seq_RNA-H2O_256_rep1_ensGene_coverage.txt       >> sample_list.txt
#
#
# ~/bin/utilities/merge_expression.py expression ~/source/bySpecies/danRer11_2/ensGene/danRer11_2.ensGene.gtf gene sample_list.txt

# %% [markdown]
# # processing

# %%
TPM = pd.read_csv('expression_TPM.txt',sep='\t',index_col=0)
TPM.head()
# Out:
#                       nanog_rFc_dome_rep4  nanog_rFc_dome_rep3  \
# Gene
# ENSDARG00000000001.6             6.223261             8.715882
# ENSDARG00000000002.8             0.675605             0.945779
# ENSDARG00000000018.9            34.480312            36.733711
# ENSDARG00000000019.9           154.777786           155.339264
# ENSDARG00000000068.9            56.704876            56.978054
#
#                       nanog_rFc_dome_rep2  nanog_rFc_dome_rep1  \
# Gene
# ENSDARG00000000001.6             7.818923             8.550631
# ENSDARG00000000002.8             0.502683             0.799011
# ENSDARG00000000018.9            35.641384            40.667027
# ENSDARG00000000019.9           143.536255           143.367126
# ENSDARG00000000068.9            56.911804            61.318932
#
#                       nanog_rFc_1k_rep4  nanog_rFc_1k_rep3  nanog_rFc_1k_rep2  \
# Gene
# ENSDARG00000000001.6          19.006306          18.242224          20.644146
# ...

# %%
TPM = TPM.loc[(TPM > 5).sum(axis=1)>=2]
TPM
# Out:
#                       nanog_rFc_dome_rep4  nanog_rFc_dome_rep3  \
# Gene
# ENSDARG00000000001.6             6.223261             8.715882
# ENSDARG00000000018.9            34.480312            36.733711
# ENSDARG00000000019.9           154.777786           155.339264
# ENSDARG00000000068.9            56.704876            56.978054
# ENSDARG00000000069.7            91.966476            89.841354
# ...                                   ...                  ...
# ENSDARG00000117732.1             2.985671             3.940239
# ENSDARG00000117744.1             5.846063             6.775061
# ENSDARG00000117778.1             3.744656             4.882837
# ENSDARG00000117786.1            29.766329            32.325611
# ENSDARG00000117824.1             4.010042             3.284220
#
#                       nanog_rFc_dome_rep2  nanog_rFc_dome_rep1  \
# Gene
# ENSDARG00000000001.6             7.818923             8.550631
# ENSDARG00000000018.9            35.641384            40.667027
# ...

# %%
input_TPM = TPM[['nanog_rFc_dome_rep3', 'nanog_rFc_dome_rep1',
                      'nanog_rFc_1k_rep4', 'nanog_rFc_1k_rep3',
                      'nanog_rFc_256_rep3', 'nanog_rFc_256_rep1',
                      'WT_dome_rep2', 'WT_dome_rep1',
                      'WT_1k_rep2', 'WT_1k_rep1',
                      'WT_256_rep2', 'WT_256_rep1',
                      'H2O_dome_rep2', 'H2O_dome_rep1', 
                      'H2O_1k_rep2', 'H2O_1k_rep1',
                      'H2O_256_rep2', 'H2O_256_rep1']
                    ]
input_TPM = input_TPM.rename(columns={"nanog_rFc_dome_rep3": "nanog_rFc_dome_rep2", 
#                                       "nanog_rFc_dome_rep3": "nanog_rFc_dome_rep1",
                                      "nanog_rFc_1k_rep4": "nanog_rFc_1k_rep2",
                                      "nanog_rFc_1k_rep3": "nanog_rFc_1k_rep1",
                                      "nanog_rFc_256_rep3": "nanog_rFc_256_rep2",
#                                       "nanog_rFc_256_rep3": "nanog_rFc_256_rep1",
                    },
           )
# input_TPM = TPM

# %% [markdown]
# ## PCA -- fig.S5E

# %%
input_TPM.T
# Out:
# Gene                 ENSDARG00000000001.6  ENSDARG00000000018.9  \
# nanog_rFc_dome_rep2              8.715882             36.733711
# nanog_rFc_dome_rep1              8.550631             40.667027
# nanog_rFc_1k_rep2               19.006306             45.981537
# nanog_rFc_1k_rep1               18.242224             40.414230
# nanog_rFc_256_rep2              21.774372             46.686905
# nanog_rFc_256_rep1              23.671156             51.963440
# WT_dome_rep2                     8.885614             39.640747
# WT_dome_rep1                     8.362440             44.267162
# WT_1k_rep2                      20.792608             51.513348
# WT_1k_rep1                      21.579258             45.011433
# WT_256_rep2                     22.822485             42.635017
# WT_256_rep1                     21.894732             42.545128
# H2O_dome_rep2                    7.409885             41.857334
# H2O_dome_rep1                    7.705432             41.316685
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(input_TPM.values.T)
# Out:
# PCA(n_components=2)

# %%
X_new = pca.transform(input_TPM.values.T)
X_new.shape
# Out:
# (18, 2)

# %%
X_new
# Out:
# array([[ -8216.74033398,   9692.88504394],
#        [ 16914.40717097,  10187.42374042],
#        [-24184.30344349,  -6503.92571409],
#        [-33024.72470438,  -7381.22043787],
#        [ 20134.50331466,  -3797.2231756 ],
#        [ 42380.00858492,   -974.68321179],
#        [ -3128.62523429,   9254.42611899],
#        [-10892.10382321,   8303.73434166],
#        [  7414.15603129,  -4209.8712423 ],
#        [-13814.51224063,  -5988.69913296],
#        [ 12996.23564079,  -3849.66083005],
#        [ -2189.76757689,  -5403.0929077 ],
#        [ -8609.85997679,   9414.42074117],
#        [-16775.31338129,   8371.01494328],
#        [  7823.99912782,  -4490.30763507],
#        [ 17740.66764627,  -2079.88474981],
#        [ -3048.95589232,  -4974.98664495],
#        [ -1519.07090947,  -5570.34924727]])

# %%
from adjustText import adjust_text

with sns.axes_style('white', rc={
        'xtick.bottom': True,
        'ytick.left': True
}), sns.plotting_context('paper',
                         rc={
                             'axes.titlesize': 14,
                             'axes.labelsize': 12,
                             'xtick.labelsize': 10,
                             'ytick.labelsize': 10,
                             'legend.fontsize': 10
                         }):
    fig, ax = plt.subplots(figsize=(6.4,4.8))
    scatters = [
                ax.scatter(np.concatenate(([np.nan], X_new[:6,0])), np.concatenate(([np.nan], X_new[:6,1])),
                          color=['black',
                                 'orange', 'orange',
                                 'blue', 'blue',
                                 'red', 'red',],
                           marker='^',
                           facecolors='none',
                           s = 100,
                           label='nanog-rFc'
                          ),
                ax.scatter(np.concatenate(([np.nan], X_new[6:12,0])), np.concatenate(([np.nan], X_new[6:12,1])),
                          color=['black',
                                 'orange', 'orange',
                                 'blue', 'blue',
                                 'red', 'red',],
                           marker='o',
                           s = 100,
                           facecolors='none',
                           label='WT'
                          ),
                ax.scatter(np.concatenate(([np.nan], X_new[12:,0])), np.concatenate(([np.nan], X_new[12:,1])),
                          color=['black',
                                 'orange', 'orange',
                                 'blue', 'blue',
                                 'red', 'red',],
                           marker='s',
                           s = 100,
                           facecolors='none',
                           label='H2O'
                          )        
               ]
#     texts = []
#     for i in range(X_new.shape[0]):
#         texts += [ax.text( 
#                           X_new[i,0], X_new[i,1],
#                           input_TPM.columns[i],
#                    )]
#     adjust_text(texts, arrowprops=dict(arrowstyle='-', color='green'))

#     l2 = ax.legend(loc='upper right', title = 'Condition', bbox_to_anchor=(.99, 1))

    import matplotlib.lines as mlines
    nanog = mlines.Line2D([], [], color='black', marker='^', linestyle='none', mfc='none',
                          markersize=10, label='nanog-rFc')
    wt = mlines.Line2D([], [], color='black', marker='o', linestyle='none', mfc='none',
                          markersize=10, label='WT')
    h2o = mlines.Line2D([], [], color='black', marker='s', linestyle='none', mfc='none',
                          markersize=10, label='H2O')
    
    l2 = ax.legend(handles=[nanog, wt, h2o], title = 'Condition', loc = 'upper right', bbox_to_anchor=(1.5, 1))

    ax.add_artist(l2)
    
    s256 = mlines.Line2D([], [], color='red', marker=None, linestyle='-', mfc='none',
                          markersize=10, label='256-cell')
    s1k = mlines.Line2D([], [], color='blue', marker=None, linestyle='-', mfc='none',
                          markersize=10, label='1k-cell')
    dome = mlines.Line2D([], [], color='orange', marker=None, linestyle='-', mfc='none',
                          markersize=10, label='dome')

    l1 = ax.legend(handles=[s256, s1k, dome], title = 'Stage', loc = 'upper right', bbox_to_anchor=(1.45, 0.65))
    ax.add_artist(l1)
    
#     ax.set_xlim(-30000,30000)
#     ax.set_ylim(-9000,11000)
    ax.set_xlabel('PCA1')
    ax.set_ylabel('PCA2')
    fig.subplots_adjust(right=.8)
    plt.tight_layout(rect=[0,0,0.75,1])

#     ax.set_title('PCA of gene expression levels under different condition')
#     fig.tight_layout()
    fig.savefig('/mnt/Storage/home/wangyiman/fitCUTRUN/revision_1/analysis/figures/Supple_Fig5E_PCA_expression.pdf',transparent=True)
